# %% [markdown]
# # Exploratory Data Analysis on Dataset - Terrorism
# As a security/defense analyst, try to find out the hot zone of terrorism. Reading and Analyzing the Dataset:
#
# Author Name - Pooja Mohan Pande.
#
# Link for the dataset: https://bit.ly/2TK5Xn5

# %% [markdown]
# # Importing the Dependencies

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Loading the dataset

# %%
dataset = pd.read_csv("C:/Users/Sneha/globalterrorismdb_0718dist.csv",encoding='ISO-8859-1')

# %%
dataset
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
dataset.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
dataset.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# # Printing the shape and features of the dataset

# %%
dataset.shape
# Out:
# (181691, 135)

# %%
dataset.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
for column in dataset.columns:
    print(column)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# weaptype1_txt
# weapsubtype1
# weapsubtype1_txt
# weaptype2
# weaptype2_txt
# weapsubtype2
# weapsubtype2_txt
# weaptype3
# weaptype3_txt
# weapsubtype3
# weapsubtype3_txt
# weaptype4
# weaptype4_txt
# weapsubtype4
# weapsubtype4_txt
# weapdetail
# nkill
# nkillus
# nkillter
# nwound
# nwoundus
# nwoundte
# property
# propextent
# propextent_txt
# propvalue
# propcomment
# ishostkid
# nhostkid
# nhostkidus
# nhours
# ndays
# divert
# kidhijcountry
# ransom
# ransomamt
# ransomamtus
# ransompaid
# ransompaidus
# ransomnote
# hostkidoutcome
# hostkidoutcome_txt
# nreleased
# addnotes
# scite1
# scite2
# scite3
# dbsource
# INT_LOG
# INT_IDEO
# INT_MISC
# INT_ANY
# related

# %% [markdown]
# # Feature Selection

# %%
data = dataset[["eventid","iyear", "imonth", "iday","gname", "country_txt", "provstate", "region_txt", 
           "longitude", "latitude", "attacktype1_txt", "target1", "nkill", "nwound", 
           "summary", "gname", "targtype1_txt", "weaptype1_txt", "motive"]]

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday                               gname  \
# 0  197000000001   1970       7     2                              MANO-D
# 1  197000000002   1970       0     0  23rd of September Communist League
# 2  197001000001   1970       1     0                             Unknown
# 3  197001000002   1970       1     0                             Unknown
# 4  197001000003   1970       1     0                             Unknown
#
#           country_txt provstate                   region_txt   longitude  \
# 0  Dominican Republic       NaN  Central America & Caribbean  -69.951164
# 1              Mexico   Federal                North America  -99.086624
# 2         Philippines    Tarlac               Southeast Asia  120.599741
# 3              Greece    Attica               Western Europe   23.762728
# 4               Japan   Fukouka                    East Asia  130.396361
#
#     latitude                 attacktype1_txt                  target1  nkill  \
# 0  18.456792                   Assassination             Julio Guzman    1.0
# 1  19.371887     Hostage Taking (Kidnapping)  Nadine Chaval, daughter    0.0
# 2  15.478598                   Assassination                 Employee    1.0
# 3  37.997490               Bombing/Explosion             U.S. Embassy    NaN
# 4  33.580412  Facility/Infrastructure Attack           U.S. Consulate    NaN
#
#    nwound summary                               gname  \
# 0     0.0     NaN                              MANO-D
# 1     0.0     NaN  23rd of September Communist League
# 2     0.0     NaN                             Unknown
# 3     NaN     NaN                             Unknown
# 4     NaN     NaN                             Unknown
#
#                  targtype1_txt weaptype1_txt motive
# 0  Private Citizens & Property       Unknown    NaN
# 1      Government (Diplomatic)       Unknown    NaN
# 2          Journalists & Media       Unknown    NaN
# 3      Government (Diplomatic)    Explosives    NaN
# 4      Government (Diplomatic)    Incendiary    NaN

# %%
data.tail()
# Out:
#              eventid  iyear  imonth  iday  \
# 181686  201712310022   2017      12    31
# 181687  201712310029   2017      12    31
# 181688  201712310030   2017      12    31
# 181689  201712310031   2017      12    31
# 181690  201712310032   2017      12    31
#
#                                              gname  country_txt  \
# 181686                                  Al-Shabaab      Somalia
# 181687                           Muslim extremists        Syria
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)  Philippines
# 181689                                     Unknown        India
# 181690                                     Unknown  Philippines
#
#               provstate                  region_txt   longitude   latitude  \
# 181686  Middle Shebelle          Sub-Saharan Africa   45.385034   2.359673
# 181687         Lattakia  Middle East & North Africa   35.942679  35.407278
# 181688      Maguindanao              Southeast Asia  124.437908   6.900742
# 181689          Manipur                  South Asia   93.940430  24.798346
# 181690      Maguindanao              Southeast Asia  124.241966   7.209594
#
#                        attacktype1_txt           target1  nkill  nwound  \
# 181686                   Armed Assault        Checkpoint    1.0     2.0
# 181687               Bombing/Explosion  Hmeymim Air Base    2.0     7.0
# 181688  Facility/Infrastructure Attack            Houses    0.0     0.0
# 181689               Bombing/Explosion            Office    0.0     0.0
# 181690               Bombing/Explosion           Unknown    0.0     0.0
#
#                                                   summary  \
# 181686  12/31/2017: Assailants opened fire on a Somali...
# 181687  12/31/2017: Assailants launched mortars at the...
# 181688  12/31/2017: Assailants set fire to houses in K...
# 181689  12/31/2017: Assailants threw a grenade at a Fo...
# 181690  12/31/2017: An explosive device was discovered...
#
#                                              gname  \
# 181686                                  Al-Shabaab
# 181687                           Muslim extremists
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)
# 181689                                     Unknown
# 181690                                     Unknown
#
#                       targtype1_txt weaptype1_txt motive
# 181686                     Military      Firearms    NaN
# 181687                     Military    Explosives    NaN
# 181688  Private Citizens & Property    Incendiary    NaN
# 181689         Government (General)    Explosives    NaN
# 181690                      Unknown    Explosives    NaN

# %% [markdown]
# # Renaming the columns of the dataset

# %%
#renaming
data.rename(columns={'eventid':'eventNo.','iyear':'Year','imonth':'Month','iday':'Day','gname':'groupname','country_txt':'Country','provstate':'State', 
                    'region_txt':'Region','longitude':'Longitude', 'latitude':'Latitude', 'attacktype1_txt':'AttackType',
                    'target1':'Target','nkill':'Killed','nwound':'Wounded','summary':'Summary','gname':'Group',
                    'targtype1_txt':'Target_type', 'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
data.head()
# Out:
#        eventNo.  Year  Month  Day                               Group  \
# 0  197000000001  1970      7    2                              MANO-D
# 1  197000000002  1970      0    0  23rd of September Communist League
# 2  197001000001  1970      1    0                             Unknown
# 3  197001000002  1970      1    0                             Unknown
# 4  197001000003  1970      1    0                             Unknown
#
#               Country    State                       Region   Longitude  \
# 0  Dominican Republic      NaN  Central America & Caribbean  -69.951164
# 1              Mexico  Federal                North America  -99.086624
# 2         Philippines   Tarlac               Southeast Asia  120.599741
# 3              Greece   Attica               Western Europe   23.762728
# 4               Japan  Fukouka                    East Asia  130.396361
#
#     Latitude                      AttackType                   Target  Killed  \
# 0  18.456792                   Assassination             Julio Guzman     1.0
# 1  19.371887     Hostage Taking (Kidnapping)  Nadine Chaval, daughter     0.0
# 2  15.478598                   Assassination                 Employee     1.0
# 3  37.997490               Bombing/Explosion             U.S. Embassy     NaN
# 4  33.580412  Facility/Infrastructure Attack           U.S. Consulate     NaN
#
#    Wounded Summary                               Group  \
# 0      0.0     NaN                              MANO-D
# 1      0.0     NaN  23rd of September Communist League
# 2      0.0     NaN                             Unknown
# 3      NaN     NaN                             Unknown
# 4      NaN     NaN                             Unknown
#
#                    Target_type Weapon_type Motive
# 0  Private Citizens & Property     Unknown    NaN
# 1      Government (Diplomatic)     Unknown    NaN
# 2          Journalists & Media     Unknown    NaN
# 3      Government (Diplomatic)  Explosives    NaN
# 4      Government (Diplomatic)  Incendiary    NaN

# %%
data.shape
# Out:
# (181691, 19)

# %%
data.isnull()
# Out:
#         eventNo.   Year  Month    Day  Group  Country  State  Region  \
# 0          False  False  False  False  False    False   True   False
# 1          False  False  False  False  False    False  False   False
# 2          False  False  False  False  False    False  False   False
# 3          False  False  False  False  False    False  False   False
# 4          False  False  False  False  False    False  False   False
# ...          ...    ...    ...    ...    ...      ...    ...     ...
# 181686     False  False  False  False  False    False  False   False
# 181687     False  False  False  False  False    False  False   False
# 181688     False  False  False  False  False    False  False   False
# 181689     False  False  False  False  False    False  False   False
# 181690     False  False  False  False  False    False  False   False
#
#         Longitude  Latitude  AttackType  Target  Killed  Wounded  Summary  \
# 0           False     False       False   False   False    False     True
# 1           False     False       False   False   False    False     True
# 2           False     False       False   False   False    False     True
# 3           False     False       False   False    True     True     True
# 4           False     False       False   False    True     True     True
# ...           ...       ...         ...     ...     ...      ...      ...
# 181686      False     False       False   False   False    False    False
# 181687      False     False       False   False   False    False    False
# 181688      False     False       False   False   False    False    False
# 181689      False     False       False   False   False    False    False
# 181690      False     False       False   False   False    False    False
#
#         Group  Target_type  Weapon_type  Motive
# 0       False        False        False    True
# 1       False        False        False    True
# 2       False        False        False    True
# 3       False        False        False    True
# 4       False        False        False    True
# ...       ...          ...          ...     ...
# 181686  False        False        False    True
# 181687  False        False        False    True
# 181688  False        False        False    True
# 181689  False        False        False    True
# 181690  False        False        False    True
#
# [181691 rows x 19 columns]

# %%
data.isnull().sum()
# Out:
# eventNo.            0
# Year                0
# Month               0
# Day                 0
# Group               0
# Country             0
# State             421
# Region              0
# Longitude        4557
# Latitude         4556
# AttackType          0
# Target            636
# Killed          10313
# Wounded         16311
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# dtype: int64

# %%
data.fillna(method='ffill', inplace=True)

# %%
data.isnull().sum()
# Out:
# eventNo.       0
# Year           0
# Month          0
# Day            0
# Group          0
# Country        0
# State          1
# Region         0
# Longitude      0
# Latitude       0
# AttackType     0
# Target         0
# Killed         0
# Wounded        0
# Summary        5
# Group          0
# Target_type    0
# Weapon_type    0
# Motive         5
# dtype: int64

# %% [markdown]
# # Displaying the shape and info of the data

# %%
data.shape
# Out:
# (181691, 19)

# %%
data.describe()
# Out:
#            eventNo.           Year          Month            Day  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#           Longitude       Latitude         Killed        Wounded
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean  -4.472081e+02      23.375299       2.488995       3.147696
# std    2.021946e+05      18.680989      11.942602      34.582571
# min   -8.618590e+07     -53.154613       0.000000       0.000000
# 25%    3.305532e+00      11.247069       0.000000       0.000000
# 50%    4.314357e+01      31.362274       0.000000       0.000000
# 75%    6.865084e+01      34.685354       2.000000       2.000000
# max    1.793667e+02      74.633553    1570.000000    8191.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   eventNo.     181691 non-null  int64
#  1   Year         181691 non-null  int64
#  2   Month        181691 non-null  int64
#  3   Day          181691 non-null  int64
#  4   Group        181691 non-null  object
#  5   Country      181691 non-null  object
#  6   State        181690 non-null  object
#  7   Region       181691 non-null  object
#  8   Longitude    181691 non-null  float64
#  9   Latitude     181691 non-null  float64
#  10  AttackType   181691 non-null  object
#  11  Target       181691 non-null  object
#  12  Killed       181691 non-null  float64
#  13  Wounded      181691 non-null  float64
#  14  Summary      181686 non-null  object
#  15  Group        181691 non-null  object
#  16  Target_type  181691 non-null  object
#  17  Weapon_type  181691 non-null  object
#  18  Motive       181686 non-null  object
# dtypes: float64(4), int64(4), object(11)
# memory usage: 26.3+ MB

# %% [markdown]
# # Correlation and Heatmap

# %%
data.corr()
# Out:
#            eventNo.      Year     Month       Day  Longitude  Latitude  \
# eventNo.   1.000000  0.999996  0.002706  0.018336   0.003800  0.169926
# Year       0.999996  1.000000  0.000139  0.018254   0.003810  0.169977
# Month      0.002706  0.000139  1.000000  0.005497  -0.003832 -0.017040
# Day        0.018336  0.018254  0.005497  1.000000  -0.002257  0.003206
# Longitude  0.003800  0.003810 -0.003832 -0.002257   1.000000  0.001425
# Latitude   0.169926  0.169977 -0.017040  0.003206   0.001425  1.000000
# Killed     0.009654  0.009641  0.005067 -0.008102  -0.000495 -0.016857
# Wounded    0.016685  0.016678  0.002595 -0.001158   0.000219  0.014845
#
#              Killed   Wounded
# eventNo.   0.009654  0.016685
# Year       0.009641  0.016678
# Month      0.005067  0.002595
# Day       -0.008102 -0.001158
# Longitude -0.000495  0.000219
# Latitude  -0.016857  0.014845
# Killed     1.000000  0.418891
# Wounded    0.418891  1.000000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %% [markdown]
# # number of unique values

# %%
data.nunique()
# Out:
# eventNo.       181691
# Year               47
# Month              13
# Day                32
# Group            3537
# Country           205
# State            2855
# Region             12
# Longitude       48039
# Latitude        48322
# AttackType          9
# Target          86006
# Killed            205
# Wounded           238
# Summary        112492
# Group            3537
# Target_type        22
# Weapon_type        12
# Motive          14490
# dtype: int64

# %% [markdown]
# # Data Visualizations:

# %%
plt.subplots(figsize=(15,6))
sns.barplot(data['Country'].value_counts()[:20].index,data['Country'].value_counts()[:20].values,palette = 'dark')
plt.title('Top 20 Countries that are Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %%
x_year = data['Year'].unique()
y_count_years = data['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,8))
sns.barplot(x = x_year, y = y_count_years, palette = 'rocket_r')
plt.xticks(rotation = 45)
plt.xlabel('Attack Year')
plt.ylabel('Number of Attacks in each year')
plt.title('Number of attacks year wise')
plt.show()

# %%
plt.subplots(figsize=(12,6))
sns.barplot(data['Region'].value_counts().index,data['Region'].value_counts().values)
plt.title('Top Regions that are Affected')
plt.xlabel('Regions')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %%
plt.subplots(figsize=(15,6))
sns.barplot(data['Country'].value_counts()[:15].index,data['Country'].value_counts()[:15].values,palette = 'viridis')
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %%
plt.subplots(figsize=(20,6))
sns.barplot(data['State'].value_counts()[:25].index,data['State'].value_counts()[:25].values,palette='YlOrBr_r')
plt.title('Top States that are Affected')
plt.xlabel('States')
plt.ylabel('Count')
plt.xticks(rotation= 90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=data['AttackType'].value_counts().index,y = data['AttackType'].value_counts().values, palette = 'dark')
plt.title('common Attack Type')
plt.xlabel('Count')
plt.xticks(rotation= 90)
plt.ylabel('Attack Type')
plt.show()

# %%
Death_each_year = data.groupby(['Year'], dropna = False)['Killed'].sum() 
fig=plt.figure(figsize=(20,7))
Death_each_year.plot(kind = 'bar', colormap = "Set2")
plt.xlabel("Years", fontsize = 12)
plt.ylabel("Number of deaths",fontsize = 12)
plt.xticks(rotation = 90)
plt.title("Number of Deaths each year")
plt.show()

# %%
fig=plt.figure(figsize=(17,7))
sns.set_style("darkgrid")
sns.kdeplot(data['Year'], hue = data['Region'])
plt.xlabel("Years")
plt.ylabel("Number of attacks")
plt.title("Number of Terrorist Attacks by Region in each year")
# Out:
# Text(0.5, 1.0, 'Number of Terrorist Attacks by Region in each year')

# %% [markdown]
# # Thank You.
